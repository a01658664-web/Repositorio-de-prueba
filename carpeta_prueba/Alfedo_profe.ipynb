# %% [markdown]
# <a href="https://colab.research.google.com/github/a01658664-web/Repositorio-de-prueba/blob/main/carpeta_prueba/Alfedo_profe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# "Este es un cambio desde mi computadore"
